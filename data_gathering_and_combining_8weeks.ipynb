# %% [markdown]
# # Data Gathering and Combining-8 weeks

# %% [markdown]
# We combine the plays data frames with the corresponding player tracking data needed for the EDA and predictive modeling. We opt to only use the first 8 weeks of the player tracking data for ease of computational processing. There are around 8 million observations using these weeks and should be enough for us to see patterns in the data.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Plays data frame

# %%
#Plays data frame 
plays_df=pd.read_csv('../nfl_data/plays.csv')
pd.set_option('display.max_columns', None)
plays_df.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1              39       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 2              39          SHOTGUN  2 RB, 1 TE, 2 WR                6.0
# 3              39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 4               1          SHOTGUN  2 RB, 3 TE, 0 WR                8.0
#
#    numberOfPassRushers        personnelD           typeDropback  \
# 0                  4.0  4 DL, 2 LB, 5 DB            TRADITIONAL
# 1                  4.0  4 DL, 2 LB, 5 DB            TRADITIONAL
# 2                  4.0  4 DL, 2 LB, 5 DB            TRADITIONAL
# 3                  5.0  4 DL, 1 LB, 6 DB  SCRAMBLE_ROLLOUT_LEFT
# 4                  6.0  6 DL, 3 LB, 2 DB            TRADITIONAL
#
#    preSnapVisitorScore  preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0                  0.0               0.0  15:00:00                    90.0
# 1                  0.0               0.0  13:10:00                    49.0
# 2                  0.0               0.0  13:05:00                    49.0
# 3                  0.0               0.0  13:01:00                    49.0
# 4                  0.0               0.0  10:59:00                    11.0
#
#   penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  playResult  \
# 0          NaN                  NaN          C                 10          10
# 1          NaN                  NaN          I                  0           0
# 2          NaN                  NaN          I                  0           0
# 3          NaN                  NaN          C                 33          33
# 4          NaN                  NaN          I                  0           0
#
#         epa  isDefensivePI
# 0  0.261827          False
# 1 -0.372360          False
# 2 -0.702779          False
# 3  3.047530          False
# 4 -0.842272          False

# %%
plays_df.playType.value_counts()
# Out:
# play_type_pass       17346
# play_type_sack        1260
# play_type_unknown      633
# Name: playType, dtype: int64

# %% [markdown]
# ### Player tracking data

# %%
#Here is the player tracking data. We will only use the first 8 weeks. 
player_tracking_week1=pd.read_csv('../nfl_data/week1.csv')
player_tracking_week2=pd.read_csv('../nfl_data/week2.csv')
player_tracking_week3=pd.read_csv('../nfl_data/week3.csv')
player_tracking_week4=pd.read_csv('../nfl_data/week4.csv')
player_tracking_week5=pd.read_csv('../nfl_data/week5.csv')
player_tracking_week6=pd.read_csv('../nfl_data/week6.csv')
player_tracking_week7=pd.read_csv('../nfl_data/week7.csv')
player_tracking_week8=pd.read_csv('../nfl_data/week8.csv')
#player_tracking_week9=pd.read_csv('../nfl_data/week9.csv')
#player_tracking_week10=pd.read_csv('../nfl_data/week10.csv')
#player_tracking_week11=pd.read_csv('../nfl_data/week11.csv')
#player_tracking_week12=pd.read_csv('../nfl_data/week12.csv')
#player_tracking_week13=pd.read_csv('../nfl_data/week13.csv')
#player_tracking_week14=pd.read_csv('../nfl_data/week14.csv')
#player_tracking_week15=pd.read_csv('../nfl_data/week15.csv')
#player_tracking_week16=pd.read_csv('../nfl_data/week16.csv')
#player_tracking_week17=pd.read_csv('../nfl_data/week17.csv')

# %% [markdown]
# How do the features in the first 8 weeks relate to the defensive formation? This could give us a baseline for the other half of the season. Because of this, we will add two new features: 'defender' and 'coverage_count'.

# %%
#Gather the first 8 weeks into one data frame 
data_path = '../nfl_data/'
player_tracking=[]
for k in range(1,9):
    player_tracking.append(pd.read_csv(data_path+'week{}.csv'.format(k)))
player_tracking_df = pd.concat(player_tracking)

# %%
player_tracking_df
# Out:
#                              time      x      y     s     a   dis       o  \
# 0        2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57
# 1        2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63
# 2        2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45
# 3        2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12
# 4        2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61
# ...                           ...    ...    ...   ...   ...   ...     ...
# 1001496  2018-10-30T03:27:40.599Z  58.83  27.06  1.62  0.13  0.16  237.81
# 1001497  2018-10-30T03:27:40.599Z  24.10  34.47  1.53  0.99  0.15  167.40
# 1001498  2018-10-30T03:27:40.599Z  14.61  43.92  4.38  1.03  0.44  154.90
# 1001499  2018-10-30T03:27:40.599Z  37.75  10.60  4.08  1.34  0.42  127.95
# 1001500  2018-10-30T03:27:40.599Z  43.62   6.09  3.32  2.94  0.35     NaN
#
#             dir event      nflId      displayName  jerseyNumber position  \
# 0        240.93  None      310.0        Matt Ryan           2.0       QB
# 1         66.66  None    79848.0  Malcolm Jenkins          27.0       SS
# 2         16.86  None  2495454.0      Julio Jones          11.0       WR
# 3        168.91  None  2495613.0     Corey Graham          24.0       FS
# 4        193.97  None  2533040.0     Mohamed Sanu          12.0       WR
# ...         ...   ...        ...              ...           ...      ...
# 1001496  241.25  None  2558191.0  Nathan Peterman           2.0       QB
# 1001497  141.69  None  2559159.0      Jason Croom          80.0       TE
# 1001498  155.86  None  2560754.0     J.C. Jackson          27.0       DB
# 1001499  141.64  None  2560801.0  Ray-Ray McCloud          14.0       WR
# 1001500     NaN  None        NaN         Football           NaN      NaN
#
#          frameId      team      gameId  playId playDirection  route
# 0              1      away  2018090600      75          left    NaN
# 1              1      home  2018090600      75          left    NaN
# 2              1      away  2018090600      75          left  HITCH
# 3              1      home  2018090600      75          left    NaN
# 4              1      away  2018090600      75          left  HITCH
# ...          ...       ...         ...     ...           ...    ...
# 1001496       86      home  2018102900    4928          left    NaN
# 1001497       86      home  2018102900    4928          left     GO
# 1001498       86      away  2018102900    4928          left    NaN
# 1001499       86      home  2018102900    4928          left   POST
# 1001500       86  football  2018102900    4928          left    NaN
#
# [8820242 rows x 19 columns]

# %%
#create a new unique Id to help get the eventual defender count
player_tracking_df['new_Id'] = player_tracking_df['gameId'].astype(str) + '_' + player_tracking_df['playId'].astype(str)
player_tracking_df.sample(10)
# Out:
#                             time       x      y     s     a   dis       o  \
# 608414  2018-09-30T19:45:22.200Z   61.94  48.93  2.61  3.80  0.28  196.35
# 60242   2018-10-19T03:16:22.200Z   60.01  21.17  5.82  3.03  0.59  167.79
# 865629  2018-10-29T00:54:12.099Z   79.10  34.41  0.39  0.40  0.04  273.76
# 875343  2018-10-22T02:15:12.099Z  107.54  34.55  1.41  0.50  0.14  258.03
# 67516   2018-09-14T02:54:07.799Z   39.12   5.32  3.54  4.29  0.37  243.30
# 566019  2018-09-09T20:29:16.799Z   78.58  27.70  1.20  3.07  0.13  307.12
# 936300  2018-09-23T22:10:54.099Z   25.58  29.72  2.15  1.09  0.21     NaN
# 780498  2018-09-30T20:47:10.900Z   83.73  33.58  3.15  2.84  0.30  130.51
# 448321  2018-10-14T18:49:29.099Z   47.76  29.70  4.03  1.77  0.41  103.89
# 644999  2018-10-07T19:54:01.000Z   88.80  23.47  0.12  3.14  0.02   40.14
#
#            dir                event      nflId          displayName  \
# 608414   94.95                 None  2560933.0       Jordan Wilkins
# 60242   195.05                 None  2543505.0         Bradley Roby
# 865629  108.37                 None  2555177.0  Mackensie Alexander
# 875343  318.59                 None  2560970.0         Jessie Bates
# 67516   107.29                 None  2543474.0     Darqueze Dennard
# 566019  308.38  pass_outcome_caught  2543720.0    Christian Kirksey
# 936300     NaN                 None        NaN             Football
# 780498   97.79                 None  2543738.0        Kareem Martin
# 448321  103.59                 None  2495807.0       Antoine Bethea
# 644999   79.94                 None  2555340.0       Kyler Fackrell
#
#         jerseyNumber position  frameId      team      gameId  playId  \
# 608414          20.0       RB       62      home  2018093004    3640
# 60242           29.0       CB       84      away  2018101800    3926
# 865629          20.0       CB       15      home  2018102811     827
# 875343          30.0        S        4      away  2018102105    2514
# 67516           21.0       CB       50      home  2018091300    3595
# 566019          58.0      OLB       60      home  2018090901    4688
# 936300           NaN      NaN       14  football  2018092310    2870
# 780498          96.0      OLB       51      home  2018093011     742
# 448321          41.0       FS       61      away  2018101405    2322
# 644999          51.0      OLB       12      away  2018100704    3831
#
#        playDirection  route           new_Id
# 608414         right  WHEEL  2018093004_3640
# 60242           left    NaN  2018101800_3926
# 865629          left    NaN   2018102811_827
# 875343         right    NaN  2018102105_2514
# 67516          right    NaN  2018091300_3595
# 566019          left    NaN  2018090901_4688
# 936300          left    NaN  2018092310_2870
# 780498         right    NaN   2018093011_742
# 448321          left    NaN  2018101405_2322
# 644999          left    NaN  2018100704_3831

# %%
player_tracking_df.position.unique()
# Out:
# array(['QB', 'SS', 'WR', 'FS', 'RB', 'MLB', 'CB', 'TE', 'LB', 'FB', nan,
#        'OLB', 'HB', 'ILB', 'DL', 'DB', 'NT', 'S', 'DE', 'P', 'LS', 'K',
#        'DT'], dtype=object)

# %%
rel_players=['QB', 'SS', 'WR', 'FS', 'RB', 'MLB', 'CB', 'TE', 'LB', 'FB','OLB', 
             'HB', 'ILB', 'DL', 'DB', 'NT', 'S', 'DE','DT']

# %%
pt_df=player_tracking_df.loc[player_tracking_df['position'].isin(rel_players)]

# %%
pt_df.head()
# Out:
#                        time      x      y     s     a   dis       o     dir  \
# 0  2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57  240.93
# 1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63   66.66
# 2  2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45   16.86
# 3  2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12  168.91
# 4  2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61  193.97
#
#   event      nflId      displayName  jerseyNumber position  frameId  team  \
# 0  None      310.0        Matt Ryan           2.0       QB        1  away
# 1  None    79848.0  Malcolm Jenkins          27.0       SS        1  home
# 2  None  2495454.0      Julio Jones          11.0       WR        1  away
# 3  None  2495613.0     Corey Graham          24.0       FS        1  home
# 4  None  2533040.0     Mohamed Sanu          12.0       WR        1  away
#
#        gameId  playId playDirection  route         new_Id
# 0  2018090600      75          left    NaN  2018090600_75
# 1  2018090600      75          left    NaN  2018090600_75
# 2  2018090600      75          left  HITCH  2018090600_75
# 3  2018090600      75          left    NaN  2018090600_75
# 4  2018090600      75          left  HITCH  2018090600_75

# %% [markdown]
# __The information below tells us that player tracking data is only given for defenders in coverage. Therefore, not all players on the field were tracked, so let's try and keep track of the number of people in coverage and who are defenders.__

# %%
#For example, defensive line. 
pt_df[pt_df.position=='DL'].displayName.unique()
#This tells us that there is only one defensive lineman in coverage situation.
# Out:
# array(['Patrick Ricard'], dtype=object)

# %%
#This tells us that there were a few defensive ends in coverage situations but not all.  
pt_df[pt_df.position=='DE'].displayName.unique()
# Out:
# array(['Leonard Williams', 'Sam Hubbard', 'Tanoh Kpassagnon',
#        'Bruce Irvin', 'Yannick Ngakoue', 'Frank Clark', 'J.J. Watt',
#        'Dee Ford', 'Jadeveon Clowney', 'Calais Campbell', 'Dante Fowler',
#        'Chris Wormley', 'Shane Ray', 'John Simon', 'Henry Anderson',
#        'Bradley Chubb', 'Myles Garrett', 'Melvin Ingram', 'Justin Lawler',
#        'Adrian Clayborn', 'Trey Flowers', 'Solomon Thomas', 'Brent Urban',
#        'William Gholston', 'Carlos Dunlap', 'Chandler Jones',
#        'Benson Mayowa', 'John Franklin-Myers', 'Everson Griffen',
#        'Stephen Weatherly'], dtype=object)

# %%
#Make a new 'defender' column to dictate who is a defender
defenders = ['SS', 'FS', 'MLB', 'CB', 'LB', 'OLB', 'ILB', 'DL', 'DB', 'NT', 'S', 'DE', 'DT']
#pt_df['defender'] = pt_df.loc[pt_df['position'].isin(defenders)]
pt_df['defender'] = pt_df['position'].isin(defenders)
# Out:
# <ipython-input-17-809d5ec4e324>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_df['defender'] = pt_df['position'].isin(defenders)

# %%
#Count the number of defenders in coverage for a specific play. Make a new 'coverage_count' column. 
count_defenders = pt_df[(pt_df['defender'] == True) & (pt_df['frameId'] == 1)].groupby('new_Id').size().reset_index(name='coverage_count')
#count_defenders.defender_count.value_counts()
pt_df = pt_df.merge(count_defenders, on='new_Id')

# %%
pt_df.head()
# Out:
#                        time      x      y     s     a   dis       o     dir  \
# 0  2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57  240.93
# 1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63   66.66
# 2  2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45   16.86
# 3  2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12  168.91
# 4  2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61  193.97
#
#   event      nflId      displayName  jerseyNumber position  frameId  team  \
# 0  None      310.0        Matt Ryan           2.0       QB        1  away
# 1  None    79848.0  Malcolm Jenkins          27.0       SS        1  home
# 2  None  2495454.0      Julio Jones          11.0       WR        1  away
# 3  None  2495613.0     Corey Graham          24.0       FS        1  home
# 4  None  2533040.0     Mohamed Sanu          12.0       WR        1  away
#
#        gameId  playId playDirection  route         new_Id  defender  \
# 0  2018090600      75          left    NaN  2018090600_75     False
# 1  2018090600      75          left    NaN  2018090600_75      True
# 2  2018090600      75          left  HITCH  2018090600_75     False
# 3  2018090600      75          left    NaN  2018090600_75      True
# 4  2018090600      75          left  HITCH  2018090600_75     False
#
#    coverage_count
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7

# %% [markdown]
# ### Combine player tracking data and the plays data to have more features for predictions.

# %%
pt_df.head()
# Out:
#                        time      x      y     s     a   dis       o     dir  \
# 0  2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57  240.93
# 1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63   66.66
# 2  2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45   16.86
# 3  2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12  168.91
# 4  2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61  193.97
#
#   event      nflId      displayName  jerseyNumber position  frameId  team  \
# 0  None      310.0        Matt Ryan           2.0       QB        1  away
# 1  None    79848.0  Malcolm Jenkins          27.0       SS        1  home
# 2  None  2495454.0      Julio Jones          11.0       WR        1  away
# 3  None  2495613.0     Corey Graham          24.0       FS        1  home
# 4  None  2533040.0     Mohamed Sanu          12.0       WR        1  away
#
#        gameId  playId playDirection  route         new_Id  defender  \
# 0  2018090600      75          left    NaN  2018090600_75     False
# 1  2018090600      75          left    NaN  2018090600_75      True
# 2  2018090600      75          left  HITCH  2018090600_75     False
# 3  2018090600      75          left    NaN  2018090600_75      True
# 4  2018090600      75          left  HITCH  2018090600_75     False
#
#    coverage_count
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7

# %%
#Recall what the plays data looks like: 
plays_df.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1              39       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 2              39          SHOTGUN  2 RB, 1 TE, 2 WR                6.0
# 3              39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 4               1          SHOTGUN  2 RB, 3 TE, 0 WR                8.0
#
#    numberOfPassRushers        personnelD           typeDropback  \
# 0                  4.0  4 DL, 2 LB, 5 DB            TRADITIONAL
# 1                  4.0  4 DL, 2 LB, 5 DB            TRADITIONAL
# 2                  4.0  4 DL, 2 LB, 5 DB            TRADITIONAL
# 3                  5.0  4 DL, 1 LB, 6 DB  SCRAMBLE_ROLLOUT_LEFT
# 4                  6.0  6 DL, 3 LB, 2 DB            TRADITIONAL
#
#    preSnapVisitorScore  preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0                  0.0               0.0  15:00:00                    90.0
# 1                  0.0               0.0  13:10:00                    49.0
# 2                  0.0               0.0  13:05:00                    49.0
# 3                  0.0               0.0  13:01:00                    49.0
# 4                  0.0               0.0  10:59:00                    11.0
#
#   penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  playResult  \
# 0          NaN                  NaN          C                 10          10
# 1          NaN                  NaN          I                  0           0
# 2          NaN                  NaN          I                  0           0
# 3          NaN                  NaN          C                 33          33
# 4          NaN                  NaN          I                  0           0
#
#         epa  isDefensivePI
# 0  0.261827          False
# 1 -0.372360          False
# 2 -0.702779          False
# 3  3.047530          False
# 4 -0.842272          False

# %%
#Combine the plays data and the player tracking data from week 1
new_df=pd.merge(pt_df, plays_df)

# %%
#Creating the necessary csv file. This csv file will be used for our predictive and EDA phases. 
pd.DataFrame(new_df).to_csv("comb_plays_track_data.csv", index = None)

# %%
#Reading in the file to make sure that it is what we wanted. 
pd.read_csv("comb_plays_track_data.csv")
# Out:
# /Users/andrewcastillo/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                              time      x      y     s     a   dis       o  \
# 0        2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57
# 1        2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63
# 2        2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45
# 3        2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12
# 4        2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61
# ...                           ...    ...    ...   ...   ...   ...     ...
# 8216291  2018-10-30T03:27:40.599Z   4.12  50.96  4.04  2.13  0.41  240.97
# 8216292  2018-10-30T03:27:40.599Z  58.83  27.06  1.62  0.13  0.16  237.81
# 8216293  2018-10-30T03:27:40.599Z  24.10  34.47  1.53  0.99  0.15  167.40
# 8216294  2018-10-30T03:27:40.599Z  14.61  43.92  4.38  1.03  0.44  154.90
# 8216295  2018-10-30T03:27:40.599Z  37.75  10.60  4.08  1.34  0.42  127.95
#
#             dir event      nflId      displayName  jerseyNumber position  \
# 0        240.93  None      310.0        Matt Ryan           2.0       QB
# 1         66.66  None    79848.0  Malcolm Jenkins          27.0       SS
# 2         16.86  None  2495454.0      Julio Jones          11.0       WR
# 3        168.91  None  2495613.0     Corey Graham          24.0       FS
# 4        193.97  None  2533040.0     Mohamed Sanu          12.0       WR
# ...         ...   ...        ...              ...           ...      ...
# 8216291  246.54  None  2557863.0        Zay Jones          11.0       WR
# 8216292  241.25  None  2558191.0  Nathan Peterman           2.0       QB
# 8216293  141.69  None  2559159.0      Jason Croom          80.0       TE
# 8216294  155.86  None  2560754.0     J.C. Jackson          27.0       DB
# 8216295  141.64  None  2560801.0  Ray-Ray McCloud          14.0       WR
#
#          frameId  team      gameId  playId playDirection  route  \
# 0              1  away  2018090600      75          left    NaN
# 1              1  home  2018090600      75          left    NaN
# 2              1  away  2018090600      75          left  HITCH
# 3              1  home  2018090600      75          left    NaN
# 4              1  away  2018090600      75          left  HITCH
# ...          ...   ...         ...     ...           ...    ...
# 8216291       86  home  2018102900    4928          left     GO
# 8216292       86  home  2018102900    4928          left    NaN
# 8216293       86  home  2018102900    4928          left     GO
# 8216294       86  away  2018102900    4928          left    NaN
# 8216295       86  home  2018102900    4928          left   POST
#
#                   new_Id  defender  coverage_count  \
# 0          2018090600_75     False               7
# 1          2018090600_75      True               7
# 2          2018090600_75     False               7
# 3          2018090600_75      True               7
# 4          2018090600_75     False               7
# ...                  ...       ...             ...
# 8216291  2018102900_4928     False               8
# 8216292  2018102900_4928     False               8
# 8216293  2018102900_4928     False               8
# 8216294  2018102900_4928      True               8
# 8216295  2018102900_4928     False               8
#
#                                            playDescription  quarter  down  \
# 0        (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 1        (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 2        (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 3        (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 4        (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# ...                                                    ...      ...   ...
# 8216291  (:58) (No Huddle, Shotgun) N.Peterman pass sho...        4     4
# 8216292  (:58) (No Huddle, Shotgun) N.Peterman pass sho...        4     4
# 8216293  (:58) (No Huddle, Shotgun) N.Peterman pass sho...        4     4
# 8216294  (:58) (No Huddle, Shotgun) N.Peterman pass sho...        4     4
# 8216295  (:58) (No Huddle, Shotgun) N.Peterman pass sho...        4     4
#
#          yardsToGo possessionTeam        playType yardlineSide  \
# 0               15            ATL  play_type_pass          ATL
# 1               15            ATL  play_type_pass          ATL
# 2               15            ATL  play_type_pass          ATL
# 3               15            ATL  play_type_pass          ATL
# 4               15            ATL  play_type_pass          ATL
# ...            ...            ...             ...          ...
# 8216291         18            BUF  play_type_pass           NE
# 8216292         18            BUF  play_type_pass           NE
# 8216293         18            BUF  play_type_pass           NE
# 8216294         18            BUF  play_type_pass           NE
# 8216295         18            BUF  play_type_pass           NE
#
#          yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0                    20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1                    20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 2                    20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 3                    20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 4                    20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# ...                 ...              ...               ...                ...
# 8216291              43          SHOTGUN  1 RB, 1 TE, 3 WR                3.0
# 8216292              43          SHOTGUN  1 RB, 1 TE, 3 WR                3.0
# 8216293              43          SHOTGUN  1 RB, 1 TE, 3 WR                3.0
# 8216294              43          SHOTGUN  1 RB, 1 TE, 3 WR                3.0
# 8216295              43          SHOTGUN  1 RB, 1 TE, 3 WR                3.0
#
#          numberOfPassRushers        personnelD typeDropback  \
# 0                        4.0  4 DL, 2 LB, 5 DB  TRADITIONAL
# 1                        4.0  4 DL, 2 LB, 5 DB  TRADITIONAL
# 2                        4.0  4 DL, 2 LB, 5 DB  TRADITIONAL
# 3                        4.0  4 DL, 2 LB, 5 DB  TRADITIONAL
# 4                        4.0  4 DL, 2 LB, 5 DB  TRADITIONAL
# ...                      ...               ...          ...
# 8216291                  3.0  3 DL, 1 LB, 7 DB  TRADITIONAL
# 8216292                  3.0  3 DL, 1 LB, 7 DB  TRADITIONAL
# 8216293                  3.0  3 DL, 1 LB, 7 DB  TRADITIONAL
# 8216294                  3.0  3 DL, 1 LB, 7 DB  TRADITIONAL
# 8216295                  3.0  3 DL, 1 LB, 7 DB  TRADITIONAL
#
#          preSnapVisitorScore  preSnapHomeScore gameClock  \
# 0                        0.0               0.0  15:00:00
# 1                        0.0               0.0  15:00:00
# 2                        0.0               0.0  15:00:00
# 3                        0.0               0.0  15:00:00
# 4                        0.0               0.0  15:00:00
# ...                      ...               ...       ...
# 8216291                 25.0               6.0  00:58:00
# 8216292                 25.0               6.0  00:58:00
# 8216293                 25.0               6.0  00:58:00
# 8216294                 25.0               6.0  00:58:00
# 8216295                 25.0               6.0  00:58:00
#
#          absoluteYardlineNumber penaltyCodes penaltyJerseyNumbers passResult  \
# 0                          90.0          NaN                  NaN          C
# 1                          90.0          NaN                  NaN          C
# 2                          90.0          NaN                  NaN          C
# 3                          90.0          NaN                  NaN          C
# 4                          90.0          NaN                  NaN          C
# ...                         ...          ...                  ...        ...
# 8216291                    53.0          NaN                  NaN          C
# 8216292                    53.0          NaN                  NaN          C
# 8216293                    53.0          NaN                  NaN          C
# 8216294                    53.0          NaN                  NaN          C
# 8216295                    53.0          NaN                  NaN          C
#
#          offensePlayResult  playResult       epa  isDefensivePI
# 0                       10          10  0.261827          False
# 1                       10          10  0.261827          False
# 2                       10          10  0.261827          False
# 3                       10          10  0.261827          False
# 4                       10          10  0.261827          False
# ...                    ...         ...       ...            ...
# 8216291                  9           9 -2.139093          False
# 8216292                  9           9 -2.139093          False
# 8216293                  9           9 -2.139093          False
# 8216294                  9           9 -2.139093          False
# 8216295                  9           9 -2.139093          False
#
# [8216296 rows x 47 columns]

# %%
#checking that it is the same format as before 
new_df.head(10)
# Out:
#                        time      x      y     s     a   dis       o     dir  \
# 0  2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57  240.93
# 1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63   66.66
# 2  2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45   16.86
# 3  2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12  168.91
# 4  2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61  193.97
# 5  2018-09-07T01:07:14.599Z  73.64  28.70  0.03  0.02  0.01  103.05  219.41
# 6  2018-09-07T01:07:14.599Z  98.25  26.63  0.01  0.01  0.00  265.88  194.51
# 7  2018-09-07T01:07:14.599Z  86.48  31.12  0.09  0.03  0.04   95.90   33.36
# 8  2018-09-07T01:07:14.599Z  82.67  20.53  0.03  0.07  0.01   81.14  174.57
# 9  2018-09-07T01:07:14.599Z  84.00  43.49  0.14  0.05  0.01  108.23  110.32
#
#   event      nflId      displayName  jerseyNumber position  frameId  team  \
# 0  None      310.0        Matt Ryan           2.0       QB        1  away
# 1  None    79848.0  Malcolm Jenkins          27.0       SS        1  home
# 2  None  2495454.0      Julio Jones          11.0       WR        1  away
# 3  None  2495613.0     Corey Graham          24.0       FS        1  home
# 4  None  2533040.0     Mohamed Sanu          12.0       WR        1  away
# 5  None  2534832.0    Rodney McLeod          23.0       FS        1  home
# 6  None  2543583.0  Devonta Freeman          24.0       RB        1  away
# 7  None  2552315.0     Jordan Hicks          58.0      MLB        1  home
# 8  None  2552689.0     Ronald Darby          21.0       CB        1  home
# 9  None  2555383.0      Jalen Mills          31.0       CB        1  home
#
#        gameId  playId playDirection  route         new_Id  defender  \
# 0  2018090600      75          left    NaN  2018090600_75     False
# 1  2018090600      75          left    NaN  2018090600_75      True
# 2  2018090600      75          left  HITCH  2018090600_75     False
# 3  2018090600      75          left    NaN  2018090600_75      True
# 4  2018090600      75          left  HITCH  2018090600_75     False
# 5  2018090600      75          left    NaN  2018090600_75      True
# 6  2018090600      75          left    NaN  2018090600_75     False
# 7  2018090600      75          left    NaN  2018090600_75      True
# 8  2018090600      75          left    NaN  2018090600_75      True
# 9  2018090600      75          left    NaN  2018090600_75      True
#
#    coverage_count                                    playDescription  quarter  \
# 0               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 1               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 2               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 3               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 4               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 5               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 6               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 7               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 8               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
# 9               7  (15:00) M.Ryan pass short right to J.Jones pus...        1
#
#    down  yardsToGo possessionTeam        playType yardlineSide  \
# 0     1         15            ATL  play_type_pass          ATL
# 1     1         15            ATL  play_type_pass          ATL
# 2     1         15            ATL  play_type_pass          ATL
# 3     1         15            ATL  play_type_pass          ATL
# 4     1         15            ATL  play_type_pass          ATL
# 5     1         15            ATL  play_type_pass          ATL
# 6     1         15            ATL  play_type_pass          ATL
# 7     1         15            ATL  play_type_pass          ATL
# 8     1         15            ATL  play_type_pass          ATL
# 9     1         15            ATL  play_type_pass          ATL
#
#    yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 2              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 3              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 4              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 5              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 6              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 7              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 8              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 9              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
#
#    numberOfPassRushers        personnelD typeDropback  preSnapVisitorScore  \
# 0                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 1                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 2                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 3                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 4                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 5                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 6                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 7                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 8                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
# 9                  4.0  4 DL, 2 LB, 5 DB  TRADITIONAL                  0.0
#
#    preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 0               0.0  15:00:00                    90.0          NaN
# 1               0.0  15:00:00                    90.0          NaN
# 2               0.0  15:00:00                    90.0          NaN
# 3               0.0  15:00:00                    90.0          NaN
# 4               0.0  15:00:00                    90.0          NaN
# 5               0.0  15:00:00                    90.0          NaN
# 6               0.0  15:00:00                    90.0          NaN
# 7               0.0  15:00:00                    90.0          NaN
# 8               0.0  15:00:00                    90.0          NaN
# 9               0.0  15:00:00                    90.0          NaN
#
#   penaltyJerseyNumbers passResult  offensePlayResult  playResult       epa  \
# 0                  NaN          C                 10          10  0.261827
# 1                  NaN          C                 10          10  0.261827
# 2                  NaN          C                 10          10  0.261827
# 3                  NaN          C                 10          10  0.261827
# 4                  NaN          C                 10          10  0.261827
# 5                  NaN          C                 10          10  0.261827
# 6                  NaN          C                 10          10  0.261827
# 7                  NaN          C                 10          10  0.261827
# 8                  NaN          C                 10          10  0.261827
# 9                  NaN          C                 10          10  0.261827
#
#    isDefensivePI
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False

# %%
#making sure our data csv is the same size as the the new_df above  
len(new_df)
# Out:
# 8216296

# %% [markdown]
# We now have the data necessary for our exploratory phase as well as predictive models.
